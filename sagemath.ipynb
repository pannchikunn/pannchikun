# %% [markdown]
# # 1 Graph each of the functions

# %% [markdown]
# $$
# \begin{equation}
#  (a)~~~  f(x) = (sin x / x)
# \end{equation}
# $$

# %%
f(x) = (sin(x)/x)
plot (f(x), (x, -10, 10))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# $$
# \begin{equation}
#  (b)~~~  y = xsin (1/x)
# \end{equation}
# $$

# %%
y = x* sin(1/x)
plot (y, (x, -2,2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# $$
# \begin{equation}
#  (c)~~~  g(x, y) = (cos x + sin y)
# \end{equation}
# $$

# %%
x, y = var('x, y')
plot3d(cos(x)+ sin(y), (x,-3, 3), (y,-3, 3))
# Out:
# Graphics3d Object

# %% [markdown]
# $$
# \begin{equation}
#  (d)~~~  z = \frac{xy}{x^2+y^2}
# \end{equation}
# $$

# %%
def z(x, y):
    return x*y/(x^2 + y^2)
P = plot3d(z, (-3,3), (-3,3))
P.show()
# Out:
# Graphics3d Object

# %% [markdown]
# $$
# \begin{equation}
#  (e)~~~  x^2 + 3y^2 = 3
# \end{equation}
# $$

# %%
x, y = var('x, y')
f_x(x, y) = x
f_y(x, y) = y
f_z(x, y) = x^2 + 3*y^2 -3
parametric_plot3d([f_x, f_y, f_z], (x, -3,3), (y,-3,3))
# Out:
# Graphics3d Object

# %% [markdown]
# $$
# \begin{equation}
#  (f)~~~  (3.9 + x^2 + y^2)^2 = 16x^2 + 16
# \end{equation}
# $$

# %%
x, y = var('x, y')
f_x(x, y) = x
f_y(x, y) = y
f_z(x, y) = (3.9 + x^2 + y^2)^2 - 16*x^2-16
parametric_plot3d([f_x, f_y, f_z], (x, -3,3), (y,-3,3))
# Out:
# Graphics3d Object

# %% [markdown]
# $$
# \begin{equation}
#  (g)~~~  (4 + x^2 + y^2)^2 = 16x^2 + 16
# \end{equation}
# $$

# %%
x, y = var('x, y')
f_x(x, y) = x
f_y(x, y) = y
f_z(x, y) = (4 + x^2 + y^2)^2 - 16*x^2-16
parametric_plot3d([f_x, f_y, f_z], (x, -3,3), (y,-3,3))
# Out:
# Graphics3d Object

# %% [markdown]
# $$
# \begin{equation}
#  (h)~~~  (4.1 + x^2 + y^2)^2 = 16x^2 + 16
# \end{equation}
# $$

# %%
x, y = var('x, y')
f_x(x, y) = x
f_y(x, y) = y
f_z(x, y) = (4.1 + x^2 + y^2)^2 - 16*x^2-16
parametric_plot3d([f_x, f_y, f_z], (x, -3,3), (y,-3,3))
# Out:
# Graphics3d Object

# %% [markdown]
# $$
# \begin{equation}
#  (i)~~~  x=sint, y=sin2t
# \end{equation}
# $$

# %%
t = var('t')
f_x(t) = sin(t)
f_y(t) = sin(2*t)
parametric_plot([f_x, f_y], (t, -4,4))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# $$
# \begin{equation}
#  (j)~~~
# x = 2\mathrm{e}^{\frac{t}{3}}cost, y = 2\mathrm{e}^{\frac{t}{3}}sint
# \end{equation}
# $$

# %%
t = var('t')
f_x(t) = 2*exp(t/3)*cos(t)
f_y(t) = 2*exp(t/3)*sin(t)
parametric_plot([f_x, f_y], (t, -4, 4))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# $$
# \begin{equation}
#  (k)~~~
# x = t - sin(t), y = 1- cos(t)
# \end{equation}
# $$

# %%
t = var('t')
f_x(t) = t - cos(t)
f_y(t) = 1 - cos(t)
parametric_plot([f_x, f_y], (t, -4, 4))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# $$
# \begin{equation}
#  (l)~~~
# x = 2t-3sint, y=2-3cost
# \end{equation}
# $$

# %%
t = var('t')
f_x(t) = 2*t - 3*cos(t)
f_y(t) = 2 - 3*cos(t)
parametric_plot([f_x, f_y], (t, -4, 4))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# #  2 Solve the linear system

# %%
x, y, z = var ('x, y, z')
solve([x+2*y+z==5, 2*x+2*y+z==6, x+2*y+2*z==7], x,y,z)
# Out:
# [[x == 1, y == 1, z == 2]]

# %% [markdown]
# #  3 Let

# %%
M = Matrix([[1,1],[1,0]])
M_2 = M*M
M_3 = M*M*M
M_4 = M*M*M*M
M_5 = M**5
M_10 = M**10
print(M, M_2,M_3,M_10)
# Out:
# ([1 1]
# [1 0], [2 1]
# [1 1], [3 2]
# [2 1], [89 55]
# [55 34])

# %% [markdown]
# #  4 Euler's conjecture

# %% [markdown]
# (a)

# %%
x_1 = 95800
x_2 = 217519
x_3 = 414560
x_4 = 422481
n = 4

x_1**n + x_2**n + x_3**n - x_4**n
# Out:
# 0

# %% [markdown]
# (b)

# %%
n = 5
x_1 =27
x_2 = 84
x_3 = 110
x_4 = 133
x_5 = 144

x_1**n + x_2**n + x_3**n + x_4**n - x_5**n
# Out:
# 0

# %% [markdown]
# #  5 Cayley-Hamilton Theorem:

# %% [markdown]
# (a)

# %%
a, b,c, d,x = var('a,b,c,d,x')
M_2 = Matrix([[a,b],[c,d]])
I_2 = Matrix([[1,0],[0,1]])

det(M_2 - x*I_2)
# Out:
# -b*c + (a - x)*(d - x)

# %% [markdown]
# (b)

# %%
M_2*M_2 - (a+d)*M_2 + (a*d - b*c)*I_2
# Out:
# [-(a + d)*a + a^2 + a*d -(a + d)*b + a*b + b*d]
# [-(a + d)*c + a*c + c*d -(a + d)*d + a*d + d^2]

# %% [markdown]
# (c)

# %%
a,b,c,d,e,f,g,h,i, x = var('a,b,c,d,e,f,g,h,i, x')
M_3 = Matrix([[a,b,c],[d,e,f],[g,h,i]])
I_3 = Matrix([[1,0,0],[0,1,0],[0,0,1]])

det(M_3 - x*I_3)
# Out:
# -(f*h - (e - x)*(i - x))*(a - x) + (c*h - b*(i - x))*d - (c*(e - x) - b*f)*g

# %% [markdown]
# (d)

# %%
S = M_3**3-(a +e+ i)*(M_3**2)-(b*d-a*e+c*g+f*h-a*i-e*i)*M_3+(c*e*g+a*f*h+b*d*i-b*f*g-c*d*h-a*e*i)*I_3

# %%
M_3a = Matrix([[1,2,3],[4,5,6],[7,8,9]])
M_3a**3-(1 +5+9)*M_3a**2-(8-5+21+48-9-45)*M_3a + (105+48+72-84-96-45)*I_3
# Out:
# [0 0 0]
# [0 0 0]
# [0 0 0]

# %% [markdown]
# #  6 Fermat Number

# %% [markdown]
# (a)

# %%
def f_n(n):
    return 2**(2**n) + 1

# %%
for i in range(1,14):
    a = f_n(i)
    print(is_prime(a))
# Out:
# True
# True
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %% [markdown]
# (b)

# %%
for i in range(5,14):
    b = f_n(i)
    print(factor(b))

# %% [markdown]
# #  7 Plucker Relation

# %%
a1,a2,a3,a4,b1,b2,b3,b4 = var('a1,a2,a3,a4,b1,b2,b3,b4')
P12 = matrix([[a1,a2],[b1,b2]])
P34 = matrix([[a3, a4],[b3, b4]])
P13 = matrix([[a1, a3], [b1, b3]])
P24 = matrix([[a2, a4], [b2, b4]])
P14 = matrix([[a1, a4], [b1, b4]])
P23 = matrix([[a2, a3],[b2, b3]])

# %%
P12*P34 - P13*P24 + P14*P23
# Out:
# [a1*a3 - a3*b2 + a4*b2 + a2*b3 a1*a3 + a4*b3 + a2*b4 - a3*b4]
# [                a3*b1 + b2*b4                 a3*b1 + b2*b4]

# %% [markdown]
# #  8 Find the positive root of the equation

# %%
def f(x):
    return x**2 -2

# %%
plot(f, (x, -5,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x = var('x')
f(x) = x**2 - 2
df = diff(f, x)
NewtonIt(x) = x - (f/df)(x)
x1 = 1.5
x2 = NewtonIt(x1)
x3 = NewtonIt(x2)
x4 = NewtonIt(x3)
print(x4)
# Out:
# 1.41421356237469

# %% [markdown]
# #    9 Compute the first 10 digits of

# %%
def sigma(func, frm, to):
    result = 0
    for i in range(frm, to + 1):
        result += func(i)
    return result

# %% [markdown]
# (a)

# %%
def f(x):
    return 1/x**2

ans = (6*sigma(f,1,10))**(1/2)
numerical_approx(ans, digits=10)
# Out:
# 3.049361636

# %% [markdown]
# (b)

# %%
ans =(6*sigma(f,1, 100))**(1/2)
numerical_approx(ans, digits=10)
# Out:
# 3.132076532

# %% [markdown]
# (c)

# %%
ans = (6*sigma(f,1,1000))**(1/2)
numerical_approx(ans, digits=10)
# Out:
# 3.140638056

# %% [markdown]
# #  10  Compute the first 30 digits of

# %%
def sigma(func, frm, to):
    result = 0
    for i in range(frm, to + 1):
        result += func(i)
    return result

def f(x):
    return (factorial(4*x)*(1103+26390*x))/((4**x)*(99**x)*factorial(x))**4

# %%
denom = (2*(2**(1/2))/(99**2))*sigma(f,0,3)
ans = 1/(denom)
numerical_approx(ans, digits=30)
# Out:
# 3.14159265358979323846264338328

# %% [markdown]
# #  11 Browein's formula

# %%
def y(n):
    if n < 1: return (2**(1/2)-1)
    return (1-(1- pow(y(n-1), 4))**(1/4)) / (1 + (1 - pow(y(n-1), 4))**(1/4))



def a(n):
    if n < 1 : return 6-4*(2**(1/2))
    return ((1 + y(n))**4)*a(n-1) - (2**(2*n + 1))*y(n)*(1 + y(n) * y(n)**2)

# %%
numerical_approx(1/a(1), digits=100)
# Out:
# 3.140487538800727248349027234218122641701265249090613572894290795179451837958402002991266631334982301

# %%
numerical_approx(1/a(2), digits=100)
# Out:
# 3.140487546171682198744435713392305737873370476648769283444185033633595453056554934113013620829699314

# %%
numerical_approx(1/a(3), digits=100)
